# %% [markdown]
# # Import CSV

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

url = "https://raw.githubusercontent.com/gabrielniculaesei/nvidia_stocks_dataset/refs/heads/main/NVDA.csv"
data = pd.read_csv(url)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6558 entries, 0 to 6557
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       6558 non-null   object
#  1   Adj Close  6558 non-null   float64
#  2   Close      6558 non-null   float64
#  3   High       6558 non-null   float64
#  4   Low        6558 non-null   float64
#  5   Open       6558 non-null   float64
#  6   Volume     6558 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 358.8+ KB

# %% [markdown]
# ## Let's check the how many nulls there are and then convert the obj type

# %%
data.isnull().sum()
# Out:
# Date         0
# Adj Close    0
# Close        0
# High         0
# Low          0
# Open         0
# Volume       0
# dtype: int64

# %%
data['Date'] = pd.to_datetime(data['Date'])

data['Hour'] = data['Date'].dt.hour
data['Minute'] = data['Date'].dt.minute

# Separate 
data['Day'] = data['Date'].dt.day
data['Month'] = data['Date'].dt.month
data['Year'] = data['Date'].dt.year

# %%
data.head(40)
# Out:
#          Date  Adj Close     Close      High       Low      Open      Volume  \
# 0  1999-01-22   0.037615  0.041016  0.048828  0.038802  0.043750  2714688000
# 1  1999-01-25   0.041556  0.045313  0.045833  0.041016  0.044271   510480000
# 2  1999-01-26   0.038331  0.041797  0.046745  0.041146  0.045833   343200000
# 3  1999-01-27   0.038212  0.041667  0.042969  0.039583  0.041927   244368000
# 4  1999-01-28   0.038092  0.041536  0.041927  0.041276  0.041667   227520000
# 5  1999-01-29   0.036301  0.039583  0.041667  0.039583  0.041536   244032000
# 6  1999-02-01   0.037018  0.040365  0.040625  0.039583  0.039583   154704000
# 7  1999-02-02   0.034152  0.037240  0.040625  0.036068  0.039583   264096000
# 8  1999-02-03   0.034869  0.038021  0.038542  0.036458  0.036719    75120000
# 9  1999-02-04   0.036779  0.040104  0.041146  0.038021  0.038542   181920000
# 10 1999-02-05   0.037854  0.041276  0.041667  0.039714  0.040755   136848000
# 11 1999-02-08   0.036540  0.039844  0.041667  0.039844  0.041536   154080000
# 12 1999-02-09   0.035107  0.038281  0.040885  0.037760  0.040625    86976000
# 13 1999-02-10   0.034749  0.037891  0.039323  0.037240  0.038281   148224000
# 14 1999-02-11   0.037734  0.041146  0.042708  0.038021  0.038021   132240000
# 15 1999-02-12   0.039884  0.043490  0.043750  0.041667  0.041667   109728000
# 16 1999-02-16   0.040122  0.043750  0.046094  0.039323  0.044271   211008000
# 17 1999-02-17   0.037973  0.041406  0.043229  0.040625  0.042708    67728000
# 18 1999-02-18   0.038570  0.042057  0.043229  0.040885  0.042708    70704000
# 19 1999-02-19   0.039884  0.043490  0.044271  0.041146  0.041667    75360000
# 20 1999-02-22   0.040122  0.043750  0.044792  0.041406  0.044271   205248000
# 21 1999-02-23   0.042033  0.045833  0.046745  0.042188  0.044792   138096000
# 22 1999-02-24   0.045376  0.049479  0.054688  0.048307  0.052604   612768000
# 23 1999-02-25   0.043944  0.047917  0.053125  0.047135  0.051563   149136000
# 24 1999-02-26   0.041914  0.045703  0.050000  0.045313  0.048438   172608000
# 25 1999-03-01   0.042153  0.045964  0.047917  0.043750  0.046875    92160000
# 26 1999-03-02   0.041794  0.045573  0.046094  0.044792  0.045833    55248000
# 27 1999-03-03   0.038928  0.042448  0.045833  0.042188  0.045833    61392000
# 28 1999-03-04   0.038092  0.041536  0.044792  0.041146  0.044531    57360000
# 29 1999-03-05   0.040242  0.043880  0.044010  0.041927  0.041927    78768000
# 30 1999-03-08   0.040839  0.044531  0.045833  0.041927  0.042708    75888000
# 31 1999-03-09   0.042153  0.045964  0.046615  0.044401  0.044401   143184000
# 32 1999-03-10   0.041436  0.045182  0.046615  0.044531  0.046615   235344000
# 33 1999-03-11   0.039645  0.043229  0.045182  0.043229  0.044401    54288000
# 34 1999-03-12   0.038928  0.042448  0.043490  0.041667  0.043490    90768000
# 35 1999-03-15   0.040600  0.044271  0.044792  0.043229  0.043490   108816000
# 36 1999-03-16   0.039287  0.042839  0.045052  0.042448  0.044531    79152000
# 37 1999-03-17   0.039525  0.043099  0.044010  0.042057  0.043229    51360000
# 38 1999-03-18   0.040003  0.043620  0.044271  0.042188  0.043229    46320000
# 39 1999-03-19   0.040122  0.043750  0.045052  0.043490  0.043490   105312000
#
#     Hour  Minute  Day  Month  Year
# 0      0       0   22      1  1999
# 1      0       0   25      1  1999
# 2      0       0   26      1  1999
# 3      0       0   27      1  1999
# 4      0       0   28      1  1999
# 5      0       0   29      1  1999
# 6      0       0    1      2  1999
# 7      0       0    2      2  1999
# 8      0       0    3      2  1999
# 9      0       0    4      2  1999
# 10     0       0    5      2  1999
# 11     0       0    8      2  1999
# 12     0       0    9      2  1999
# 13     0       0   10      2  1999
# 14     0       0   11      2  1999
# 15     0       0   12      2  1999
# 16     0       0   16      2  1999
# 17     0       0   17      2  1999
# 18     0       0   18      2  1999
# 19     0       0   19      2  1999
# 20     0       0   22      2  1999
# 21     0       0   23      2  1999
# 22     0       0   24      2  1999
# 23     0       0   25      2  1999
# 24     0       0   26      2  1999
# 25     0       0    1      3  1999
# 26     0       0    2      3  1999
# 27     0       0    3      3  1999
# 28     0       0    4      3  1999
# 29     0       0    5      3  1999
# 30     0       0    8      3  1999
# 31     0       0    9      3  1999
# 32     0       0   10      3  1999
# 33     0       0   11      3  1999
# 34     0       0   12      3  1999
# 35     0       0   15      3  1999
# 36     0       0   16      3  1999
# 37     0       0   17      3  1999
# 38     0       0   18      3  1999
# 39     0       0   19      3  1999

# %% [markdown]
# # Overall distribution

# %%
plt.figure(figsize=(12,5))
plt.plot(data["Date"], data["Close"])
plt.title("NVDA Close Price (2015–2025)")
plt.ylabel("Close")
plt.xlabel("Date")
plt.show()

# %% [markdown]
# Let's focus on the 2020-2025 part since, that's where we had a peak

# %%
plt.figure(figsize=(12,5))
filtered_data = data[data["Year"]>2019]
plt.plot(filtered_data["Date"], filtered_data["Close"])
plt.title("NVDA Close Price (2015–2025)")
plt.ylabel("Close")
plt.xlabel("Date")
plt.show()
